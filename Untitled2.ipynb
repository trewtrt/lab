# %% [markdown]
# <a href="https://colab.research.google.com/github/trewtrt/lab/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# найти массу
# дано
import numpy as np
import matplotlib.pyplot as plt
T=np.linspace(0,400,100) #Кельвин
P=101325 # Паскаоль
V=64 #м^3
R =8.314
# Решение 1
M =0.016
m=(P*V*M)/(R*T) # функция
plt.plot(T,m)
plt.show
print(" Масса",m)
# Out:
# <ipython-input-9-10468cb4d368>:11: RuntimeWarning: divide by zero encountered in true_divide
#   m=(P*V*M)/(R*T)
#  Масса [          inf 3088.7428434  1544.3714217  1029.5809478   772.18571085
#   617.74856868  514.7904739   441.24897763  386.09285542  343.19364927
#   308.87428434  280.79480395  257.39523695  237.59560334  220.62448881
#   205.91618956  193.04642771  181.69075549  171.59682463  162.56541281
#   154.43714217  147.08299254  140.39740197  134.2931671   128.69761847
#   123.54971374  118.79780167  114.39788309  110.31224441  106.50837391
#   102.95809478   99.63686592   96.52321386   93.59826798   90.84537775
#    88.24979553   85.79841232   83.47953631   81.28270641   79.19853445
#    77.21857108   75.3351913    73.54149627   71.83122892   70.19870099
#    68.63872985   67.14658355   65.71793284   64.34880924   63.03556823
#    61.77485687   60.56358516   59.39890083   58.27816686   57.19894154
#    56.15896079   55.1561222    54.18847094   53.25418696   52.35157362
# ...

# %%
pip install CoolProp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 47.9 MB/s eta 0:00:00
# ...

# %%
import CoolProp.CoolProp as ct
import numpy as np
import matplotlib.pyplot as plt
Fluid_name="CH4"
t=np.linspace(100,400,500)
V=64
p=101325
d=ct.PropsSI("D","P",p,"T",t,Fluid_name)
m=d*V
plt.plot(t,m,"r")
plt.title("график")
plt.xlabel("температура")
plt.ylabel("давление")
plt.grid()

T=np.linspace(0,400,500)
R=8
m=(P*V*M)/(R*T)
plt.scatter(373,46,color="g")
plt.plot(T,m)
plt.show()
print(m)
# Out:
# <ipython-input-42-5f30f8d95142>:18: RuntimeWarning: divide by zero encountered in true_divide
#   m=(P*V*M)/(R*T)
# [           inf 16179.576       8089.788       5393.192
#   4044.894       3235.9152      2696.596       2311.368
#   2022.447       1797.73066667  1617.9576      1470.87054545
#   1348.298       1244.58276923  1155.684       1078.6384
#   1011.2235       951.73976471   898.86533333   851.55663158
#    808.9788       770.456        735.43527273   703.45982609
#    674.149        647.18304      622.29138462   599.24355556
#    577.842        557.91641379   539.3192       521.92180645
#    505.61175      490.29018182   475.86988235   462.2736
#    449.43266667   437.28583784   425.77831579   414.86092308
#    404.4894       394.62380488   385.228        376.2692093
#    367.71763636   359.54613333   351.72991304   344.24629787
#    337.0745       330.19542857   323.59152      317.24658824
#    311.14569231   305.27501887   299.62177778   294.17410909
# ...
